# %% [markdown]
# # Solving battleship with many algorithms

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./results.csv", index_col=0)

df.describe()
# Out:
#               Random       Improved         Hunter         Parity  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean      343.755910      95.397970      67.253380      62.363940
# std       125.180658       4.803357      12.662001       8.449465
# min        68.000000      52.000000      25.000000      25.000000
# 25%       255.000000      93.000000      58.000000      57.000000
# 50%       322.000000      97.000000      67.000000      63.000000
# 75%       407.000000      99.000000      76.000000      69.000000
# max      1562.000000     100.000000     105.000000      84.000000
#
#        Full Knowledge
# count   100000.000000
# mean        59.399100
# std         10.035791
# min         22.000000
# 25%         53.000000
# 50%         60.000000
# 75%         67.000000
# max         92.000000

# %%
data = pd.DataFrame({
    'Random': df["Random"].value_counts().sort_index(),
    'Improved': df["Improved"].value_counts().sort_index(),
    'Hunter': df["Hunter"].value_counts().sort_index(),
    'Parity': df["Parity"].value_counts().sort_index(),
    'Full Knowledge': df["Full Knowledge"].value_counts().sort_index()
}).fillna(0)

# %%
plt.figure(figsize=(10,6))

for col in data.columns:
    plt.plot(data.index, data[col], label=col)

plt.title('Shots taken by each algorithm')
plt.xlabel('Number of shots')
plt.ylabel('Frequency')
plt.legend()
plt.xlim(20, 100)
plt.grid(True)
plt.show()
